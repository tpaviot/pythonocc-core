# %%
import sys
sys.path.append('..')
from core_classic_occ_bottle import bottle

# %%
from OCC.Display.WebGl import jupyter_renderer
ren = jupyter_renderer.JupyterRenderer()

# %%
ren.DisplayShape(bottle, render_edges=True, topo_level="Face")

# %%
ren
